# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mp
import datetime as dt
import pandas as pd
import numpy as np
import pylab as pl
import seaborn as sns

# %%
df = pd.read_excel("yelp.xlsx")

# %%
for i in range(len(df)):
    check = df.ix[i,'category'].find(",\n")
    if check!=-1:
        df.ix[i,'category'] = df.ix[i,'category'][0:check]
df
# Out:
#                                     restaurant_name                category  \
# 0            1.         Sottocasa Pizzeria - Harlem                   Pizza
# 1                            2.         BLVD Bistro  American (Traditional)
# 2                          3.         Marlow Bistro           Mediterranean
# 3                             4.         Babbalucci                 Italian
# 4                               5.         Max Soha                 Italian
# 5                  6.         Publique Espresso Bar                   Cafes
# 6                   7.         LoLo’s Seafood Shack                 Seafood
# 7                               8.         Pisticci                 Italian
# 8                               9.         Flat Top          American (New)
# 9                         10.         Chapati House                  Indian
# 10                                 11.         Lido                 Italian
# ...

# %%
d = {}
for i,r in dfzip.iterrows():
    if not r[1] in d:
        d[r[1]]=1
        continue
    d[r[1]]=d[r[1]]+1
#remove all of them less than 10
s = {}
for i in d:
    if d[i]>10:
        s[i]=d[i]

# %%
X = np.arange(len(s))
pl.bar(X, sorted(s.values()), align='center', width=0.5)
pl.xticks(X, sorted(s,key=s.get),rotation=90)
ymax = max(sorted(s.values())) + 1
pl.ylim(0, ymax)
pl.show()

# %%
sns.countplot(zip25['rating'])
